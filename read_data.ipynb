# %%
import pandas as pd

# %%
df = pd.read_csv('2013-04-10.csv')

# %%
df.head()
# Out:
#          date   serial_number                    model  capacity_bytes  \
# 0  2013-04-10  MJ0351YNG9Z0XA  Hitachi HDS5C3030ALA630   3000592982016
# 1  2013-04-10  MJ0351YNG9WJSA  Hitachi HDS5C3030ALA630   3000592982016
# 2  2013-04-10  MJ0351YNG9Z7LA  Hitachi HDS5C3030ALA630   3000592982016
# 3  2013-04-10  MJ0351YNGAD37A  Hitachi HDS5C3030ALA630   3000592982016
# 4  2013-04-10  MJ0351YNGABYAA  Hitachi HDS5C3030ALA630   3000592982016
#
#    failure  smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 0        0                 NaN            0                 NaN          NaN
# 1        0                 NaN            0                 NaN          NaN
# 2        0                 NaN            0                 NaN          NaN
# 3        0                 NaN            0                 NaN          NaN
# 4        0                 NaN            0                 NaN          NaN
#
#    smart_3_normalized  ...  smart_250_normalized  smart_250_raw  \
# ...
